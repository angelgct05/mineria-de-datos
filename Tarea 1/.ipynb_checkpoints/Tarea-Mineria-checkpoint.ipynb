# %% [markdown]
# # Preparación de Datos
#
# Importar las librerías.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Leer los datos desde un csv y transformamos a utf8.

# %%
df = pd.read_csv("unclean_data1.csv")
df = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %% [markdown]
# Realizo una prueba para corroborar que los datos hayan sido leídos correctamente.

# %%
df
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Visualizo los primeros 5 datos de la tabla.

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# Posteriormente veo los últimos 5 datos de la tabla.

# %%
df.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %% [markdown]
# Para seguir estudiando la tabla, también obtengo el nombre de cada una de sus columnas.

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# Cambiaremos el nombre de las columnas a español.

# %%
df = df.rename(columns = {'movie_title':'titulo_pelicula', 'num_critic_for_reviews':'numero_criticas', 'duration':'duracion', 'DIRECTOR_facebook_likes':'likes_en_fb_DIRECTOR', 'actor_3_facebook_likes':'likes_en_fb_ACTOR_3', 'ACTOR_1_facebook_likes':'likes_en_fb_ACTOR_1', 'gross':'ganancia', 'num_voted_users':'num_usuarios_votados', 'Cast_Total_facebook_likes':'likes_en_fb_CAST_TOTAL', 'facenumber_in_poster':'num_face_en_poster', 'num_user_for_reviews':'num_usuarios_para_revision', 'budget':'presupuesto', 'title_year':'anio', 'ACTOR_2_facebook_likes':'likes_en_fb_ACTOR_2', 'imdb_score':'puntuacion_imdb', 'title_year.1':'anio.1'})
df.columns
# Out:
# Index(['titulo_pelicula', 'numero_criticas', 'duracion',
#        'likes_en_fb_DIRECTOR', 'likes_en_fb_ACTOR_3', 'likes_en_fb_ACTOR_1',
#        'ganancia', 'num_usuarios_votados', 'likes_en_fb_CAST_TOTAL',
#        'num_face_en_poster', 'num_usuarios_para_revision', 'presupuesto',
#        'anio', 'likes_en_fb_ACTOR_2', 'puntuacion_imdb', 'anio.1'],
#       dtype='object')

# %% [markdown]
# Como queremos trabajar solo con los likes en facebook del director, dejaremos esas columnas junto con el nombre de las películas para referenciarla.

# %%
df = df.drop(['numero_criticas', 'likes_en_fb_ACTOR_1', 'likes_en_fb_ACTOR_3', 'likes_en_fb_CAST_TOTAL', 'likes_en_fb_ACTOR_2', 'duracion', 'ganancia', 'num_usuarios_votados', 'num_face_en_poster', 'num_usuarios_para_revision', 'presupuesto', 'anio', 'puntuacion_imdb', 'anio.1'],axis = 1 )

# %%
df.isnull().sum()
# Out:
# titulo_pelicula         0
# likes_en_fb_DIRECTOR    2
# dtype: int64

# %%
df.dtypes
# Out:
# titulo_pelicula         object
# likes_en_fb_DIRECTOR    object
# dtype: object

# %% [markdown]
# Intentaré cambiart todas las columnas a enteros ya que no se pueden medios likes.

# %%
df['likes_en_fb_DIRECTOR'] = df['likes_en_fb_DIRECTOR'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-ea44bc1b91b5> in <module>
# ----> 1 df['likes_en_fb_DIRECTOR'] = df['likes_en_fb_DIRECTOR'].astype('Int64')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %% [markdown]
# Como vemos no es posible convertirlo debido a que hay un elemento que no es numérico por lo que en una base de datos enorme no podríamos revisarlo, lo volveremos nulo y seguiremos casteando a int.

# %%
df['likes_en_fb_DIRECTOR'] = pd.to_numeric(df['likes_en_fb_DIRECTOR'], errors='coerce')
df['likes_en_fb_DIRECTOR'] = df['likes_en_fb_DIRECTOR'].astype('Int64')

# %% [markdown]
# Corroboramos que haya funcionado...

# %%
df.dtypes
# Out:
# titulo_pelicula         object
# likes_en_fb_DIRECTOR     Int64
# dtype: object

# %%
df
# Out:
#                                  titulo_pelicula  likes_en_fb_DIRECTOR
# 0                                       Avatar?ÿ                    10
# 1     Pirates of the Caribbean: At World's End?ÿ                   563
# 2                                      Spectre?ÿ                    20
# 3                        The Dark Knight Rises?ÿ                 22000
# 4                                  John Carter?ÿ                   NaN
# 5                                 Spider-Man 3?ÿ                    23
# 6                                      Tangled?ÿ                    15
# 7                      Avengers: Age of Ultron?ÿ                    10
# 8                      Avengers: Age of Ultron?ÿ                    10
# 9       Harry Potter and the Half-Blood Prince?ÿ                   282
# 10          Batman v Superman: Dawn of Justice?ÿ                   NaN
# 11                            Superman Returns?ÿ                   NaN
# ...

# %% [markdown]
# Ahora hay algo que me llama la atención y es Avengers: Age of Ultron que se encuentra duplicado, o no? lo veremos con el siguiente comando:

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %% [markdown]
# Como hemos visto, se encuentra duplicado por lo que pasaremos a eliminar su duplicado.

# %%
df = df.drop_duplicates()
df
# Out:
#                                  titulo_pelicula  likes_en_fb_DIRECTOR
# 0                                       Avatar?ÿ                    10
# 1     Pirates of the Caribbean: At World's End?ÿ                   563
# 2                                      Spectre?ÿ                    20
# 3                        The Dark Knight Rises?ÿ                 22000
# 4                                  John Carter?ÿ                   NaN
# 5                                 Spider-Man 3?ÿ                    23
# 6                                      Tangled?ÿ                    15
# 7                      Avengers: Age of Ultron?ÿ                    10
# 9       Harry Potter and the Half-Blood Prince?ÿ                   282
# 10          Batman v Superman: Dawn of Justice?ÿ                   NaN
# 11                            Superman Returns?ÿ                   NaN
# 12                           Quantum of Solace?ÿ                   395
# ...

# %% [markdown]
# Ahora ordenamos de mayor a nulo los datos.

# %%
df = df.sort_values(by=['likes_en_fb_DIRECTOR'], ascending=[False])
df
# Out:
#                                  titulo_pelicula  likes_en_fb_DIRECTOR
# 3                        The Dark Knight Rises?ÿ                 22000
# 1     Pirates of the Caribbean: At World's End?ÿ                   563
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                   563
# 12                           Quantum of Solace?ÿ                   395
# 9       Harry Potter and the Half-Blood Prince?ÿ                   282
# 5                                 Spider-Man 3?ÿ                    23
# 2                                      Spectre?ÿ                    20
# 6                                      Tangled?ÿ                    15
# 0                                       Avatar?ÿ                    10
# 7                      Avengers: Age of Ultron?ÿ                    10
# 4                                  John Carter?ÿ                   NaN
# 10          Batman v Superman: Dawn of Justice?ÿ                   NaN
# ...

# %% [markdown]
# Ya vimos ordenados los datos e incluso vimos que el dato 8 era duplicado por lo que haremos un ciclo para determinar a donde va cada fila. Ordenaremos por Miles, Cientos, Algunos y Nulos likes.

# %%
clase_miles = object
clase_cientos = object
clase_pocos = object
clase_nulos = object
i=0

# %%
while i<=len(df):
    if i!=8:
        if df.loc[i, 'likes_en_fb_DIRECTOR'] > 999:
            clase_miles = df[df['likes_en_fb_DIRECTOR']=='clase_miles']
        elif df.loc[i, 'likes_en_fb_DIRECTOR'] > 99 and df.loc[i, 'likes_en_fb_DIRECTOR'] <= 999 :
            clase_cientos = df[df['likes_en_fb_DIRECTOR']=='clase_cientos']
        elif df.loc[i, 'likes_en_fb_DIRECTOR'] <= 99:
            clase_pocos = df[df['likes_en_fb_DIRECTOR']=='clase_pocos']
        else:
            clase_nulos = df[df['likes_en_fb_DIRECTOR']=='clase_nulos']
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-eee08e1a356d> in <module>
#       6             clase_cientos = df[df['likes_en_fb_DIRECTOR']=='clase_cientos']
#       7         elif df.loc[i, 'likes_en_fb_DIRECTOR'] <= 99:
# ----> 8             clase_pocos = df[df['likes_en_fb_DIRECTOR']=='clase_pocos']
#       9         else:
#      10             clase_nulos = df[df['likes_en_fb_DIRECTOR']=='clase_nulos']
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1190             # Note: the `not is_scalar(other)` condition rules out
#    1191             # e.g. other == "category"
# -> 1192             return dispatch_to_extension_op(op, self, other)
#    1193
#    1194         elif isinstance(other, ABCSeries):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_extension_op(op, left, right)
# ...
